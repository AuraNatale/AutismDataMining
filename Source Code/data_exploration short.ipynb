# %%
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
import seaborn as sns 
import re
import OurFunctions as of
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import ParameterGrid

#import missingno as msno

# %%
ASD_phenotypic_original = pd.read_csv(os.path.join('DataSets','Phenotypic Datasets','ASD_phenotypic.csv'))

# %% [markdown]
# # DATA EXPLORATION

# %% [markdown]
# Visualization of the overall dataset

# %%
ASD_phenotypic_original
# Out:
#       SITE_ID  SUB_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  SEX  \
# 0     CALTECH   51456         1          4        55.40    1
# 1     CALTECH   51457         1          4        22.90    1
# 2     CALTECH   51458         1          1        39.20    1
# 3     CALTECH   51459         1          1        22.80    1
# 4     CALTECH   51460         1          1        34.60    2
# ...       ...     ...       ...        ...          ...  ...
# 1107     YALE   50624         1          3        11.08    2
# 1108     YALE   50625         1          3         7.00    1
# 1109     YALE   50626         1          3        11.08    1
# 1110     YALE   50627         1          3         9.50    2
# 1111     YALE   50628         1          3        14.42    1
#
#      HANDEDNESS_CATEGORY  HANDEDNESS_SCORES    FIQ    VIQ  ...  \
# 0                      R                NaN  126.0  118.0  ...
# 1                   Ambi                NaN  107.0  119.0  ...
# 2                      R                NaN   93.0   80.0  ...
# 3                      R                NaN  106.0   94.0  ...
# 4                   Ambi                NaN  133.0  135.0  ...
# ...                  ...                ...    ...    ...  ...
# 1107                   R                NaN   90.0   91.0  ...
# 1108                   L                NaN   99.0   90.0  ...
# 1109                   L                NaN   61.0   66.0  ...
# 1110                   R                NaN   88.0  103.0  ...
# 1111                   R                NaN   77.0   72.0  ...
#
#       WISC_IV_BLK_DSN_SCALED WISC_IV_PIC_CON_SCALED WISC_IV_MATRIX_SCALED  \
# 0                        NaN                    NaN                   NaN
# 1                        NaN                    NaN                   NaN
# 2                        NaN                    NaN                   NaN
# 3                        NaN                    NaN                   NaN
# 4                        NaN                    NaN                   NaN
# ...                      ...                    ...                   ...
# 1107                     NaN                    NaN                   NaN
# 1108                     NaN                    NaN                   NaN
# 1109                     NaN                    NaN                   NaN
# 1110                     NaN                    NaN                   NaN
# 1111                     NaN                    NaN                   NaN
#
#      WISC_IV_DIGIT_SPAN_SCALED  WISC_IV_LET_NUM_SCALED  WISC_IV_CODING_SCALED  \
# 0                          NaN                     NaN                    NaN
# 1                          NaN                     NaN                    NaN
# 2                          NaN                     NaN                    NaN
# 3                          NaN                     NaN                    NaN
# 4                          NaN                     NaN                    NaN
# ...                        ...                     ...                    ...
# 1107                       NaN                     NaN                    NaN
# 1108                       NaN                     NaN                    NaN
# 1109                       NaN                     NaN                    NaN
# 1110                       NaN                     NaN                    NaN
# 1111                       NaN                     NaN                    NaN
#
#       WISC_IV_SYM_SCALED  EYE_STATUS_AT_SCAN  AGE_AT_MPRAGE  BMI
# 0                    NaN                   2            NaN  NaN
# 1                    NaN                   2            NaN  NaN
# 2                    NaN                   2            NaN  NaN
# 3                    NaN                   2            NaN  NaN
# 4                    NaN                   2            NaN  NaN
# ...                  ...                 ...            ...  ...
# 1107                 NaN                   1            NaN  NaN
# 1108                 NaN                   1            NaN  NaN
# 1109                 NaN                   1            NaN  NaN
# 1110                 NaN                   1            NaN  NaN
# 1111                 NaN                   1            NaN  NaN
#
# [1112 rows x 74 columns]

# %% [markdown]
# The dataset contains 1112 subjects and has 74 features.
#
#  By a fast view we can see that there are both categorical and numerical values and there are missing values. Also, we can see the presence of the categories DX_GROUP and DSM_IV_TR, that are described from the ABIDE dataset legend as diagnostic, so we will further remove them from the dataset for the model predictor construction. We can also think about delete the feature EYE_STATUS_AT_SCAN, because it's informing about the fact the eyes of the subject were open or not during the fMRI, so it's not relevant information for us in this moment.

# %% [markdown]
# DX_GROUP and DSM_IV_TR are our targets.
# DX_GROUP contains info about the presence (or not) of autism spectrum.
# DSM_IV_TR specifyes which kind of autism.
# However, in our investigation, we are interested only on evaluate the presence or not of the disease, so we will not consider the information in DSM_IV_TR.

# %% [markdown]
# To know if the dataset is balanced we plot the distribution of the unique values in DX_GROUP, that correspond to the labels.

# %%
# Calcola il conteggio delle classi per DX_GROUP
class_counts_DX_GROUP = ASD_phenotypic_original['DX_GROUP'].value_counts()


# Stampa il conteggio delle classi per DX_GROUP
print("Conteggio delle classi per DX_GROUP:")
print(class_counts_DX_GROUP)

# Visualizza la distribuzione delle classi per DX_GROUP
class_counts_DX_GROUP.plot(kind='bar', color='blue')
plt.title('Distribuzione delle classi per DX_GROUP')
plt.xlabel('Classe')
plt.ylabel('Numero di campioni')
plt.xticks(rotation=0)
plt.show()

# Calcola le proporzioni delle classi per DX_GROUP
class_proportions_DX_GROUP = ASD_phenotypic_original['DX_GROUP'].value_counts(normalize=True)

# Stampa le proporzioni delle classi per DX_GROUP
print("\nProporzioni delle classi per DX_GROUP:")
print(class_proportions_DX_GROUP)
# Out:
# Conteggio delle classi per DX_GROUP:
# DX_GROUP
# 2    573
# 1    539
# Name: count, dtype: int64
# Proporzioni delle classi per DX_GROUP:
# DX_GROUP
# 2    0.515288
# 1    0.484712
# Name: proportion, dtype: float64

# %% [markdown]
# DX_GROUP is balanced.

# %% [markdown]
# Now, to have a better view of the information contained in the dataset we display the names of the features and the respective types and quantity of non-null values.

# %%
ASD_phenotypic_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1112 entries, 0 to 1111
# Data columns (total 74 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   SITE_ID                          1112 non-null   object
#  1   SUB_ID                           1112 non-null   int64
#  2   DX_GROUP                         1112 non-null   int64
#  3   DSM_IV_TR                        1112 non-null   int64
#  4   AGE_AT_SCAN                      1112 non-null   float64
#  5   SEX                              1112 non-null   int64
#  6   HANDEDNESS_CATEGORY              797 non-null    object
#  7   HANDEDNESS_SCORES                370 non-null    float64
#  8   FIQ                              1077 non-null   float64
#  9   VIQ                              935 non-null    float64
#  10  PIQ                              953 non-null    float64
#  11  FIQ_TEST_TYPE                    947 non-null    object
#  12  VIQ_TEST_TYPE                    834 non-null    object
#  13  PIQ_TEST_TYPE                    853 non-null    object
#  14  ADI_R_SOCIAL_TOTAL_A             412 non-null    float64
#  15  ADI_R_VERBAL_TOTAL_BV            412 non-null    float64
#  16  ADI_RRB_TOTAL_C                  412 non-null    float64
#  17  ADI_R_ONSET_TOTAL_D              331 non-null    float64
#  18  ADI_R_RSRCH_RELIABLE             411 non-null    float64
#  19  ADOS_MODULE                      535 non-null    float64
#  20  ADOS_TOTAL                       442 non-null    float64
#  21  ADOS_COMM                        417 non-null    float64
#  22  ADOS_SOCIAL                      417 non-null    float64
#  23  ADOS_STEREO_BEHAV                378 non-null    float64
#  24  ADOS_RSRCH_RELIABLE              380 non-null    float64
#  25  ADOS_GOTHAM_SOCAFFECT            317 non-null    float64
#  26  ADOS_GOTHAM_RRB                  317 non-null    float64
#  27  ADOS_GOTHAM_TOTAL                317 non-null    float64
#  28  ADOS_GOTHAM_SEVERITY             317 non-null    float64
#  29  SRS_VERSION                      269 non-null    float64
#  30  SRS_RAW_TOTAL                    405 non-null    float64
#  31  SRS_AWARENESS                    64 non-null     float64
#  32  SRS_COGNITION                    64 non-null     float64
#  33  SRS_COMMUNICATION                64 non-null     float64
#  34  SRS_MOTIVATION                   64 non-null     float64
#  35  SRS_MANNERISMS                   64 non-null     float64
#  36  SCQ_TOTAL                        143 non-null    float64
#  37  AQ_TOTAL                         58 non-null     float64
#  38  COMORBIDITY                      64 non-null     object
#  39  CURRENT_MED_STATUS               817 non-null    object
#  40  MEDICATION_NAME                  157 non-null    object
#  41  OFF_STIMULANTS_AT_SCAN           141 non-null    float64
#  42  VINELAND_RECEPTIVE_V_SCALED      184 non-null    float64
#  43  VINELAND_EXPRESSIVE_V_SCALED     184 non-null    float64
#  44  VINELAND_WRITTEN_V_SCALED        184 non-null    float64
#  45  VINELAND_COMMUNICATION_STANDARD  184 non-null    float64
#  46  VINELAND_PERSONAL_V_SCALED       184 non-null    float64
#  47  VINELAND_DOMESTIC_V_SCALED       184 non-null    float64
#  48  VINELAND_COMMUNITY_V_SCALED      184 non-null    float64
#  49  VINELAND_DAILYLVNG_STANDARD      184 non-null    float64
#  50  VINELAND_INTERPERSONAL_V_SCALED  184 non-null    float64
#  51  VINELAND_PLAY_V_SCALED           184 non-null    float64
#  52  VINELAND_COPING_V_SCALED         184 non-null    float64
#  53  VINELAND_SOCIAL_STANDARD         184 non-null    float64
#  54  VINELAND_SUM_SCORES              184 non-null    float64
#  55  VINELAND_ABC_STANDARD            184 non-null    float64
#  56  VINELAND_INFORMANT               184 non-null    float64
#  57  WISC_IV_VCI                      55 non-null     float64
#  58  WISC_IV_PRI                      55 non-null     float64
#  59  WISC_IV_WMI                      55 non-null     float64
#  60  WISC_IV_PSI                      55 non-null     float64
#  61  WISC_IV_SIM_SCALED               55 non-null     float64
#  62  WISC_IV_VOCAB_SCALED             55 non-null     float64
#  63  WISC_IV_INFO_SCALED              55 non-null     float64
#  64  WISC_IV_BLK_DSN_SCALED           55 non-null     float64
#  65  WISC_IV_PIC_CON_SCALED           55 non-null     float64
#  66  WISC_IV_MATRIX_SCALED            55 non-null     float64
#  67  WISC_IV_DIGIT_SPAN_SCALED        55 non-null     float64
#  68  WISC_IV_LET_NUM_SCALED           55 non-null     float64
#  69  WISC_IV_CODING_SCALED            55 non-null     float64
#  70  WISC_IV_SYM_SCALED               55 non-null     float64
#  71  EYE_STATUS_AT_SCAN               1112 non-null   int64
#  72  AGE_AT_MPRAGE                    101 non-null    float64
#  73  BMI                              214 non-null    float64
# dtypes: float64(61), int64(5), object(8)
# memory usage: 643.0+ KB

# %%
ASD_phenotypic_original.describe(include = 'object').T
# Out:
#                     count unique               top freq
# SITE_ID              1112     20               NYU  184
# HANDEDNESS_CATEGORY   797      6                 R  693
# FIQ_TEST_TYPE         947     13              WASI  551
# VIQ_TEST_TYPE         834     14              WASI  508
# PIQ_TEST_TYPE         853     15              WASI  508
# COMORBIDITY            64     43  ADHD Inattentive    7
# CURRENT_MED_STATUS    817      4                 0  673
# MEDICATION_NAME       157    103                 0   24

# %% [markdown]
# As we can see, there is an important presence of missing values. Also, there are both numerical type features and object type (which is the default way to label the categorical data.)

# %% [markdown]
# In order to have a better view of the distribution of the null values, we check the presence of missing values catalogated as None or numpy.NaN

# %%
# Count of the missing values

nan_values = ASD_phenotypic_original.isna().sum() 
nan_sorted = nan_values.sort_values(ascending=False)

total_rows = ASD_phenotypic_original.shape[0]
percent_missing = (nan_sorted / total_rows) * 100

# We implemented a function "select_columns", that is able to define wich columns are numerical
# and which ones are categorical (also redefine the objects as categorical in the dataset)
numeric_columns, categorical_columns, ASD_phenotypic_original = of.select_columns(ASD_phenotypic_original)

# We plot the distribution of missing values, with the specification of numeric and categorical columns
of.plot_missing_values(percent_missing, numeric_columns, legend=True)

# %% [markdown]
# For the majority of the features the amount of missing values is not depreciable, so we can say that the information that is stored in the feature is not enough to create a reliable classier/cluster algortihm based on it. The same comment can be done for the subjects. We need to work on a dataset that has a maximum of 10% of missing values per feature, so we need to clean this in some way.

# %% [markdown]
# Now let's have a look on the general statistics for the numerical attributes.

# %%
ASD_phenotypic_original.describe()
# Out:
#              SUB_ID     DX_GROUP    DSM_IV_TR  AGE_AT_SCAN          SEX  \
# count   1112.000000  1112.000000  1112.000000  1112.000000  1112.000000
# mean   50752.684353     1.515288  -646.819245    17.048864     1.147482
# std      447.680666     0.499991  2461.828856     8.036419     0.354745
# min    50002.000000     1.000000 -9999.000000     6.470000     1.000000
# 25%    50354.750000     1.000000     0.000000    11.658575     1.000000
# 50%    50724.500000     2.000000     0.000000    14.660000     1.000000
# 75%    51153.250000     2.000000     1.000000    20.085000     1.000000
# max    51607.000000     2.000000     4.000000    64.000000     2.000000
#
#        HANDEDNESS_SCORES          FIQ          VIQ          PIQ  \
# count         370.000000  1077.000000   935.000000   953.000000
# mean         -102.560892  -238.854968   -86.757219  -126.663169
# std          1273.177790  1841.858322  1389.584584  1518.469557
# min         -9999.000000 -9999.000000 -9999.000000 -9999.000000
# 25%            48.000000    98.000000    97.000000    96.000000
# 50%            75.000000   108.000000   108.000000   107.000000
# 75%            91.000000   119.000000   119.000000   117.000000
# max           100.000000   148.000000   180.000000   157.000000
#
#        ADI_R_SOCIAL_TOTAL_A  ...  WISC_IV_BLK_DSN_SCALED  \
# count            412.000000  ...               55.000000
# mean            -807.024272  ...               11.636364
# std             2760.138808  ...                3.014555
# min            -9999.000000  ...                4.000000
# 25%               14.000000  ...               10.000000
# 50%               20.000000  ...               11.000000
# 75%               24.000000  ...               13.000000
# max               30.000000  ...               19.000000
#
#        WISC_IV_PIC_CON_SCALED  WISC_IV_MATRIX_SCALED  \
# count               55.000000              55.000000
# mean                 9.909091              11.545455
# std                  3.187201               2.651472
# min                  3.000000               7.000000
# 25%                  7.000000              10.000000
# 50%                 11.000000              11.000000
# 75%                 12.000000              12.500000
# max                 15.000000              19.000000
#
#        WISC_IV_DIGIT_SPAN_SCALED  WISC_IV_LET_NUM_SCALED  \
# count                  55.000000               55.000000
# mean                   10.127273               10.363636
# std                     3.232099                2.914610
# min                     2.000000                2.000000
# 25%                     7.500000                9.500000
# 50%                    10.000000               11.000000
# 75%                    12.500000               12.000000
# max                    17.000000               14.000000
#
#        WISC_IV_CODING_SCALED  WISC_IV_SYM_SCALED  EYE_STATUS_AT_SCAN  \
# count              55.000000           55.000000         1112.000000
# mean                8.763636            9.890909            1.312050
# std                 2.821634            2.753266            0.463539
# min                 4.000000            1.000000            1.000000
# 25%                 7.000000            8.000000            1.000000
# 50%                 9.000000           10.000000            1.000000
# 75%                10.500000           12.000000            2.000000
# max                15.000000           16.000000            2.000000
#
#        AGE_AT_MPRAGE          BMI
# count     101.000000   214.000000
# mean      -86.176535 -5597.902757
# std       996.228820  4984.307763
# min     -9999.000000 -9999.000000
# 25%        11.250000 -9999.000000
# 50%        12.900000 -9999.000000
# 75%        14.440000    18.817500
# max        17.940000    35.430000
#
# [8 rows x 66 columns]

# %% [markdown]
# We can notice the presence of "-9999" as minimum value for different features, a value that is commonly used to denote missing data or values out of range, so it should be better to consider them as NaN.

# %% [markdown]
# Now that we have an overall view of the dataset, let's start to work on it in order to clean it.

# %% [markdown]
# # DATASET CLEANING

# %% [markdown]
# First of all, we decided to apart the features that give the diagnosis of the subjects (DX_GROUP and DSM_IV_TR), in order to use them as the control labels.
#
# We also drop EYE_STATUS_AT_SCAN, that it's not relevant feature for this analysis.

# %%
ASD_phenotypic = ASD_phenotypic_original.drop(columns=['DSM_IV_TR','EYE_STATUS_AT_SCAN'])

# %% [markdown]
# Also we decide to drop SUB_ID, as it only store the information about the ID of the subject. But before we check if there aren't replicated subjects. Then if we don't find any duplicate, we can simply drop the column.

# %%
# Check if there are duplicate values in the 'SUB_ID' column
duplicate_ids = ASD_phenotypic['SUB_ID'].duplicated(keep=False)

# Get the unique duplicate IDs
unique_duplicate_ids = ASD_phenotypic.loc[duplicate_ids, 'SUB_ID'].unique()

#Drop column if there aren't duplicates
if len(unique_duplicate_ids) == 0:
    ASD_phenotypic = ASD_phenotypic.drop(columns=['SUB_ID'])
    print("SUB_ID was dropped")
else:
    print("There are replicated values:" + str(unique_duplicate_ids))
# Out:
# SUB_ID was dropped

# %% [markdown]
# In order to have a real count of the amount of missing values per feature, we change the -9999 values present in the overall data to np.NaN (we can make this because we know from the datasheets that -9999 is a value out of range for all the features).

# %%
for column in ASD_phenotypic:
    
    # Replace -9999 and "-9999" with NaN
    ASD_phenotypic[column] = ASD_phenotypic[column].replace(['-9999', -9999], np.NaN)
# Out:
# C:\Users\auran\AppData\Local\Temp\ipykernel_3288\1707501323.py:4: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   ASD_phenotypic[column] = ASD_phenotypic[column].replace(['-9999', -9999], np.NaN)

# %% [markdown]
# We also notice that there are two features that indicates if the personal that took the tests is a trained professional or not (ADI_R_RSRCH_RELIABLE and ADOS_RSRCH_RELIABLE ). This is information is interesting to determine if the scores achieved in the respective tests are reliable or not. In order to avoid include not reliable information, we decide to eliminate the subjects that has a 0 in both categories (not reliable), while if the value is 1 or missed, we maintain the subject.

# %%
# Create a mask for rows to keep
filter = (ASD_phenotypic['ADI_R_RSRCH_RELIABLE'] != 0) | (ASD_phenotypic['ADOS_RSRCH_RELIABLE'] != 0)

# Calculate the number of subjects to delete
deleted_subjects = len(ASD_phenotypic) - filter.sum()

# Apply the mask to both DataFrames
ASD_phenotypic= ASD_phenotypic[filter].copy()
#ASD_clinical = ASD_clinical[filter].copy() 

# Print the number of subjects deleted
print("Number of subjects deleted:", deleted_subjects)

ASD_phenotypic = ASD_phenotypic.drop(columns=['ADI_R_RSRCH_RELIABLE','ADOS_RSRCH_RELIABLE'])
# Out:
# Number of subjects deleted: 26

# %%
ASD_phenotypic
# Out:
#       SITE_ID  DX_GROUP  AGE_AT_SCAN  SEX HANDEDNESS_CATEGORY  \
# 0     CALTECH         1        55.40    1                   R
# 1     CALTECH         1        22.90    1                Ambi
# 2     CALTECH         1        39.20    1                   R
# 3     CALTECH         1        22.80    1                   R
# 4     CALTECH         1        34.60    2                Ambi
# ...       ...       ...          ...  ...                 ...
# 1107     YALE         1        11.08    2                   R
# 1108     YALE         1         7.00    1                   L
# 1109     YALE         1        11.08    1                   L
# 1110     YALE         1         9.50    2                   R
# 1111     YALE         1        14.42    1                   R
#
#       HANDEDNESS_SCORES    FIQ    VIQ    PIQ FIQ_TEST_TYPE  ...  \
# 0                   NaN  126.0  118.0  128.0          WASI  ...
# 1                   NaN  107.0  119.0   93.0          WASI  ...
# 2                   NaN   93.0   80.0  108.0          WASI  ...
# 3                   NaN  106.0   94.0  118.0          WASI  ...
# 4                   NaN  133.0  135.0  122.0          WASI  ...
# ...                 ...    ...    ...    ...           ...  ...
# 1107                NaN   90.0   91.0   89.0     DAS_II_SA  ...
# 1108                NaN   99.0   90.0   98.0     DAS_II_SA  ...
# 1109                NaN   61.0   66.0   60.0     DAS_II_SA  ...
# 1110                NaN   88.0  103.0   84.0     DAS_II_SA  ...
# 1111                NaN   77.0   72.0   75.0     DAS_II_SA  ...
#
#      WISC_IV_INFO_SCALED WISC_IV_BLK_DSN_SCALED  WISC_IV_PIC_CON_SCALED  \
# 0                    NaN                    NaN                     NaN
# 1                    NaN                    NaN                     NaN
# 2                    NaN                    NaN                     NaN
# 3                    NaN                    NaN                     NaN
# 4                    NaN                    NaN                     NaN
# ...                  ...                    ...                     ...
# 1107                 NaN                    NaN                     NaN
# 1108                 NaN                    NaN                     NaN
# 1109                 NaN                    NaN                     NaN
# 1110                 NaN                    NaN                     NaN
# 1111                 NaN                    NaN                     NaN
#
#       WISC_IV_MATRIX_SCALED  WISC_IV_DIGIT_SPAN_SCALED  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
# ...                     ...                        ...
# 1107                    NaN                        NaN
# 1108                    NaN                        NaN
# 1109                    NaN                        NaN
# 1110                    NaN                        NaN
# 1111                    NaN                        NaN
#
#       WISC_IV_LET_NUM_SCALED  WISC_IV_CODING_SCALED  WISC_IV_SYM_SCALED  \
# 0                        NaN                    NaN                 NaN
# 1                        NaN                    NaN                 NaN
# 2                        NaN                    NaN                 NaN
# 3                        NaN                    NaN                 NaN
# 4                        NaN                    NaN                 NaN
# ...                      ...                    ...                 ...
# 1107                     NaN                    NaN                 NaN
# 1108                     NaN                    NaN                 NaN
# 1109                     NaN                    NaN                 NaN
# 1110                     NaN                    NaN                 NaN
# 1111                     NaN                    NaN                 NaN
#
#       AGE_AT_MPRAGE  BMI
# 0               NaN  NaN
# 1               NaN  NaN
# 2               NaN  NaN
# 3               NaN  NaN
# 4               NaN  NaN
# ...             ...  ...
# 1107            NaN  NaN
# 1108            NaN  NaN
# 1109            NaN  NaN
# 1110            NaN  NaN
# 1111            NaN  NaN
#
# [1086 rows x 69 columns]

# %%
# Visualizzazione dei missing values
# msno.matrix(ASD_phenotypic)

# %%
# Supponiamo di avere un DataFrame chiamato ASD_phenotypic
# Ecco un esempio di come potrebbe essere il tuo DataFrame
# ASD_phenotypic = pd.read_csv('your_dataset.csv')

# Features chiave da mantenere
key_features = ['FIQ', 'VIQ', 'PIQ', 'ADI_R_VERBAL_TOTAL_BV', 'ADOS_TOTAL']

def calculate_missing_percentage(df):
    total_values = df.size
    missing_values = df.isna().sum().sum()
    return (missing_values / total_values) * 100


def remove_high_missing(df, key_features, balance_column, min_subjects=200, max_missing_percentage=10):
    current_df = df.copy()
    
    # Calcolare la proporzione iniziale del bilanciamento
    initial_balance = current_df[balance_column].value_counts(normalize=True)
    
    while (calculate_missing_percentage(current_df) > max_missing_percentage): 
        # Calcola la percentuale di valori mancanti per ciascuna colonna e riga
        missing_percent_features = current_df.isna().mean() * 100
        missing_percent_subjects = current_df.isna().mean(axis=1) * 100
        
        # Filtra le features chiave per non rimuoverle
        non_key_features = missing_percent_features.drop(labels=key_features, errors='ignore')
        
        # Trova la feature o il soggetto con il più alto tasso di missing values
        max_feature_missing = non_key_features.max()
        max_subject_missing = missing_percent_subjects.max()
        
        # Rimuovi la feature o il soggetto con il tasso di missing values più alto
        if max_feature_missing >= max_subject_missing and not non_key_features.empty:
            feature_to_drop = non_key_features.idxmax()
            current_df = current_df.drop(columns=[feature_to_drop])
            print(f"Rimosso feature: {feature_to_drop}")
        elif not missing_percent_subjects.empty:
            scelto_soggetto = False
            while not scelto_soggetto:
                subject_to_drop = missing_percent_subjects.idxmax()
                temp_df = current_df.drop(index=[subject_to_drop])
            
             # Verifica il bilanciamento dopo la rimozione
                current_balance = temp_df[balance_column].value_counts(normalize=True)
                if all(abs(initial_balance - current_balance) <= 0.2):  # Assicurarsi che il bilanciamento non cambi di più del 20%
                    current_df = temp_df
                    scelto_soggetto = True
                    print(f"Rimosso soggetto: {subject_to_drop}")
                else:
                    id = missing_percent_subjects.drop(subject_to_drop)
                    print(f"Soggetto non rimosso per mantenere il bilanciamento: {subject_to_drop}")
            

        # Controllo dello stato attuale del DataFrame
        print(f"Percentuale attuale di missing values: {calculate_missing_percentage(current_df):.2f}%")
        if current_df.shape[0] > min_subjects:
            print(f"Numero di soggetti rimanenti: {current_df.shape[0]}")
    
    return current_df


# Applica la funzione di pulizia sul DataFrame
ASD_phenotypic_cleaned = remove_high_missing(ASD_phenotypic, key_features, balance_column='DX_GROUP', min_subjects=200, max_missing_percentage=10)

# Mostra le prime righe del DataFrame pulito
print(ASD_phenotypic_cleaned.head())

# Salva il DataFrame pulito
ASD_phenotypic_cleaned.to_csv('ASDPhenotipic_cleaned_dataset.csv', index=False)

ASD_phenotypic_cleaned
# Out:
# Rimosso feature: AQ_TOTAL
# Percentuale attuale di missing values: 73.00%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: WISC_IV_VCI
# Percentuale attuale di missing values: 72.67%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: WISC_IV_PRI
# Percentuale attuale di missing values: 72.33%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: WISC_IV_WMI
# Percentuale attuale di missing values: 71.99%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: WISC_IV_PSI
# Percentuale attuale di missing values: 71.63%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: WISC_IV_SIM_SCALED
# Percentuale attuale di missing values: 71.26%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: WISC_IV_VOCAB_SCALED
# Percentuale attuale di missing values: 70.88%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: WISC_IV_INFO_SCALED
# Percentuale attuale di missing values: 70.48%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: WISC_IV_BLK_DSN_SCALED
# Percentuale attuale di missing values: 70.07%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: WISC_IV_PIC_CON_SCALED
# Percentuale attuale di missing values: 69.65%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: WISC_IV_MATRIX_SCALED
# Percentuale attuale di missing values: 69.22%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: WISC_IV_DIGIT_SPAN_SCALED
# Percentuale attuale di missing values: 68.77%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: WISC_IV_LET_NUM_SCALED
# Percentuale attuale di missing values: 68.30%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: WISC_IV_CODING_SCALED
# Percentuale attuale di missing values: 67.81%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: WISC_IV_SYM_SCALED
# Percentuale attuale di missing values: 67.31%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: COMORBIDITY
# Percentuale attuale di missing values: 66.80%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: SRS_AWARENESS
# Percentuale attuale di missing values: 66.27%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: SRS_COGNITION
# Percentuale attuale di missing values: 65.73%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: SRS_COMMUNICATION
# Percentuale attuale di missing values: 65.16%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: SRS_MOTIVATION
# Percentuale attuale di missing values: 64.57%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: SRS_MANNERISMS
# Percentuale attuale di missing values: 63.95%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: OFF_STIMULANTS_AT_SCAN
# Percentuale attuale di missing values: 63.33%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: BMI
# Percentuale attuale di missing values: 62.70%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: AGE_AT_MPRAGE
# Percentuale attuale di missing values: 62.08%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: VINELAND_RECEPTIVE_V_SCALED
# Percentuale attuale di missing values: 61.45%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: VINELAND_EXPRESSIVE_V_SCALED
# Percentuale attuale di missing values: 60.79%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: VINELAND_WRITTEN_V_SCALED
# Percentuale attuale di missing values: 60.10%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: VINELAND_COMMUNICATION_STANDARD
# Percentuale attuale di missing values: 59.38%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: VINELAND_PERSONAL_V_SCALED
# Percentuale attuale di missing values: 58.63%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: VINELAND_DOMESTIC_V_SCALED
# Percentuale attuale di missing values: 57.83%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: VINELAND_COMMUNITY_V_SCALED
# Percentuale attuale di missing values: 56.99%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: VINELAND_DAILYLVNG_STANDARD
# Percentuale attuale di missing values: 56.11%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: VINELAND_INTERPERSONAL_V_SCALED
# Percentuale attuale di missing values: 55.17%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: VINELAND_PLAY_V_SCALED
# Percentuale attuale di missing values: 54.19%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: VINELAND_COPING_V_SCALED
# Percentuale attuale di missing values: 53.14%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: VINELAND_SOCIAL_STANDARD
# Percentuale attuale di missing values: 52.04%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: VINELAND_SUM_SCORES
# Percentuale attuale di missing values: 50.86%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: VINELAND_ABC_STANDARD
# Percentuale attuale di missing values: 49.61%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: VINELAND_INFORMANT
# Percentuale attuale di missing values: 48.27%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: SCQ_TOTAL
# Percentuale attuale di missing values: 46.88%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: MEDICATION_NAME
# Percentuale attuale di missing values: 45.50%
# Numero di soggetti rimanenti: 1086
# Rimosso feature: SRS_VERSION
# Percentuale attuale di missing values: 44.27%
# Numero di soggetti rimanenti: 1086
# Rimosso soggetto: 546
# Percentuale attuale di missing values: 44.24%
# Numero di soggetti rimanenti: 1085
# Rimosso soggetto: 547
# Percentuale attuale di missing values: 44.21%
# Numero di soggetti rimanenti: 1084
# Rimosso soggetto: 548
# Percentuale attuale di missing values: 44.17%
# Numero di soggetti rimanenti: 1083
# Rimosso soggetto: 549
# Percentuale attuale di missing values: 44.14%
# Numero di soggetti rimanenti: 1082
# Rimosso soggetto: 550
# Percentuale attuale di missing values: 44.11%
# Numero di soggetti rimanenti: 1081
# Rimosso soggetto: 551
# Percentuale attuale di missing values: 44.08%
# Numero di soggetti rimanenti: 1080
# Rimosso soggetto: 552
# Percentuale attuale di missing values: 44.05%
# Numero di soggetti rimanenti: 1079
# Rimosso soggetto: 553
# Percentuale attuale di missing values: 44.02%
# Numero di soggetti rimanenti: 1078
# Rimosso soggetto: 554
# Percentuale attuale di missing values: 43.99%
# Numero di soggetti rimanenti: 1077
# Rimosso soggetto: 555
# Percentuale attuale di missing values: 43.96%
# Numero di soggetti rimanenti: 1076
# Rimosso soggetto: 556
# Percentuale attuale di missing values: 43.92%
# Numero di soggetti rimanenti: 1075
# Rimosso soggetto: 557
# Percentuale attuale di missing values: 43.89%
# Numero di soggetti rimanenti: 1074
# Rimosso soggetto: 558
# Percentuale attuale di missing values: 43.86%
# Numero di soggetti rimanenti: 1073
# Rimosso soggetto: 559
# Percentuale attuale di missing values: 43.83%
# Numero di soggetti rimanenti: 1072
# Rimosso soggetto: 560
# Percentuale attuale di missing values: 43.80%
# Numero di soggetti rimanenti: 1071
# Rimosso soggetto: 566
# Percentuale attuale di missing values: 43.77%
# Numero di soggetti rimanenti: 1070
# Rimosso soggetto: 567
# Percentuale attuale di missing values: 43.73%
# Numero di soggetti rimanenti: 1069
# Rimosso feature: ADOS_GOTHAM_SOCAFFECT
# Percentuale attuale di missing values: 42.51%
# Numero di soggetti rimanenti: 1069
# Rimosso feature: ADOS_GOTHAM_RRB
# Percentuale attuale di missing values: 41.20%
# Numero di soggetti rimanenti: 1069
# Rimosso feature: ADOS_GOTHAM_TOTAL
# Percentuale attuale di missing values: 39.80%
# Numero di soggetti rimanenti: 1069
# Rimosso feature: ADOS_GOTHAM_SEVERITY
# Percentuale attuale di missing values: 38.28%
# Numero di soggetti rimanenti: 1069
# Rimosso feature: ADI_R_ONSET_TOTAL_D
# Percentuale attuale di missing values: 36.69%
# Numero di soggetti rimanenti: 1069
# Rimosso feature: ADOS_STEREO_BEHAV
# Percentuale attuale di missing values: 35.09%
# Numero di soggetti rimanenti: 1069
# Rimosso feature: HANDEDNESS_SCORES
# Percentuale attuale di missing values: 33.43%
# Numero di soggetti rimanenti: 1069
# Rimosso feature: ADI_R_SOCIAL_TOTAL_A
# Percentuale attuale di missing values: 31.67%
# Numero di soggetti rimanenti: 1069
# Rimosso feature: ADI_RRB_TOTAL_C
# Percentuale attuale di missing values: 29.71%
# Numero di soggetti rimanenti: 1069
# Rimosso feature: ADOS_COMM
# Percentuale attuale di missing values: 27.57%
# Numero di soggetti rimanenti: 1069
# Rimosso feature: ADOS_SOCIAL
# Percentuale attuale di missing values: 25.18%
# Numero di soggetti rimanenti: 1069
# Rimosso feature: SRS_RAW_TOTAL
# Percentuale attuale di missing values: 22.47%
# Numero di soggetti rimanenti: 1069
# Rimosso feature: ADOS_MODULE
# Percentuale attuale di missing values: 20.15%
# Numero di soggetti rimanenti: 1069
# Rimosso soggetto: 438
# Percentuale attuale di missing values: 20.12%
# Numero di soggetti rimanenti: 1068
# Rimosso soggetto: 439
# Percentuale attuale di missing values: 20.09%
# Numero di soggetti rimanenti: 1067
# Rimosso soggetto: 440
# Percentuale attuale di missing values: 20.06%
# Numero di soggetti rimanenti: 1066
# Rimosso soggetto: 441
# Percentuale attuale di missing values: 20.03%
# Numero di soggetti rimanenti: 1065
# Rimosso soggetto: 442
# Percentuale attuale di missing values: 20.01%
# Numero di soggetti rimanenti: 1064
# Rimosso soggetto: 443
# Percentuale attuale di missing values: 19.98%
# Numero di soggetti rimanenti: 1063
# Rimosso soggetto: 444
# Percentuale attuale di missing values: 19.95%
# Numero di soggetti rimanenti: 1062
# Rimosso soggetto: 445
# Percentuale attuale di missing values: 19.92%
# Numero di soggetti rimanenti: 1061
# Rimosso soggetto: 446
# Percentuale attuale di missing values: 19.89%
# Numero di soggetti rimanenti: 1060
# Rimosso soggetto: 447
# Percentuale attuale di missing values: 19.86%
# Numero di soggetti rimanenti: 1059
# Rimosso soggetto: 448
# Percentuale attuale di missing values: 19.84%
# Numero di soggetti rimanenti: 1058
# Rimosso soggetto: 449
# Percentuale attuale di missing values: 19.81%
# Numero di soggetti rimanenti: 1057
# Rimosso soggetto: 450
# Percentuale attuale di missing values: 19.78%
# Numero di soggetti rimanenti: 1056
# Rimosso soggetto: 451
# Percentuale attuale di missing values: 19.75%
# Numero di soggetti rimanenti: 1055
# Rimosso soggetto: 452
# Percentuale attuale di missing values: 19.72%
# Numero di soggetti rimanenti: 1054
# Rimosso soggetto: 466
# Percentuale attuale di missing values: 19.69%
# Numero di soggetti rimanenti: 1053
# Rimosso soggetto: 469
# Percentuale attuale di missing values: 19.66%
# Numero di soggetti rimanenti: 1052
# Rimosso soggetto: 473
# Percentuale attuale di missing values: 19.63%
# Numero di soggetti rimanenti: 1051
# Rimosso soggetto: 474
# Percentuale attuale di missing values: 19.61%
# Numero di soggetti rimanenti: 1050
# Rimosso soggetto: 475
# Percentuale attuale di missing values: 19.58%
# Numero di soggetti rimanenti: 1049
# Rimosso soggetto: 476
# Percentuale attuale di missing values: 19.55%
# Numero di soggetti rimanenti: 1048
# Rimosso soggetto: 477
# Percentuale attuale di missing values: 19.52%
# Numero di soggetti rimanenti: 1047
# Rimosso soggetto: 478
# Percentuale attuale di missing values: 19.49%
# Numero di soggetti rimanenti: 1046
# Rimosso soggetto: 479
# Percentuale attuale di missing values: 19.46%
# Numero di soggetti rimanenti: 1045
# Rimosso soggetto: 480
# Percentuale attuale di missing values: 19.43%
# Numero di soggetti rimanenti: 1044
# Rimosso soggetto: 481
# Percentuale attuale di missing values: 19.40%
# Numero di soggetti rimanenti: 1043
# Rimosso soggetto: 482
# Percentuale attuale di missing values: 19.37%
# Numero di soggetti rimanenti: 1042
# Rimosso soggetto: 483
# Percentuale attuale di missing values: 19.34%
# Numero di soggetti rimanenti: 1041
# Rimosso soggetto: 484
# Percentuale attuale di missing values: 19.31%
# Numero di soggetti rimanenti: 1040
# Rimosso soggetto: 485
# Percentuale attuale di missing values: 19.28%
# Numero di soggetti rimanenti: 1039
# Rimosso soggetto: 486
# Percentuale attuale di missing values: 19.25%
# Numero di soggetti rimanenti: 1038
# Rimosso soggetto: 487
# Percentuale attuale di missing values: 19.22%
# Numero di soggetti rimanenti: 1037
# Rimosso soggetto: 488
# Percentuale attuale di missing values: 19.19%
# Numero di soggetti rimanenti: 1036
# Rimosso soggetto: 569
# Percentuale attuale di missing values: 19.16%
# Numero di soggetti rimanenti: 1035
# Rimosso soggetto: 65
# Percentuale attuale di missing values: 19.14%
# Numero di soggetti rimanenti: 1034
# Rimosso soggetto: 66
# Percentuale attuale di missing values: 19.12%
# Numero di soggetti rimanenti: 1033
# Rimosso soggetto: 67
# Percentuale attuale di missing values: 19.10%
# Numero di soggetti rimanenti: 1032
# Rimosso soggetto: 68
# Percentuale attuale di missing values: 19.07%
# Numero di soggetti rimanenti: 1031
# Rimosso soggetto: 69
# Percentuale attuale di missing values: 19.05%
# Numero di soggetti rimanenti: 1030
# Rimosso soggetto: 70
# Percentuale attuale di missing values: 19.03%
# Numero di soggetti rimanenti: 1029
# Rimosso soggetto: 71
# Percentuale attuale di missing values: 19.00%
# Numero di soggetti rimanenti: 1028
# Rimosso soggetto: 72
# Percentuale attuale di missing values: 18.98%
# Numero di soggetti rimanenti: 1027
# Rimosso soggetto: 73
# Percentuale attuale di missing values: 18.96%
# Numero di soggetti rimanenti: 1026
# Rimosso soggetto: 74
# Percentuale attuale di missing values: 18.93%
# Numero di soggetti rimanenti: 1025
# Rimosso soggetto: 75
# Percentuale attuale di missing values: 18.91%
# Numero di soggetti rimanenti: 1024
# Rimosso soggetto: 76
# Percentuale attuale di missing values: 18.89%
# Numero di soggetti rimanenti: 1023
# Rimosso soggetto: 77
# Percentuale attuale di missing values: 18.86%
# Numero di soggetti rimanenti: 1022
# Rimosso soggetto: 78
# Percentuale attuale di missing values: 18.84%
# Numero di soggetti rimanenti: 1021
# Rimosso soggetto: 79
# Percentuale attuale di missing values: 18.82%
# Numero di soggetti rimanenti: 1020
# Rimosso soggetto: 80
# Percentuale attuale di missing values: 18.79%
# Numero di soggetti rimanenti: 1019
# Rimosso soggetto: 81
# Percentuale attuale di missing values: 18.77%
# Numero di soggetti rimanenti: 1018
# Rimosso soggetto: 82
# Percentuale attuale di missing values: 18.75%
# Numero di soggetti rimanenti: 1017
# Rimosso soggetto: 83
# Percentuale attuale di missing values: 18.72%
# Numero di soggetti rimanenti: 1016
# Rimosso soggetto: 101
# Percentuale attuale di missing values: 18.70%
# Numero di soggetti rimanenti: 1015
# Rimosso soggetto: 102
# Percentuale attuale di missing values: 18.67%
# Numero di soggetti rimanenti: 1014
# Rimosso soggetto: 103
# Percentuale attuale di missing values: 18.65%
# Numero di soggetti rimanenti: 1013
# Rimosso soggetto: 104
# Percentuale attuale di missing values: 18.63%
# Numero di soggetti rimanenti: 1012
# Rimosso soggetto: 105
# Percentuale attuale di missing values: 18.60%
# Percentuale attuale di missing values: 10.71%
# Numero di soggetti rimanenti: 748
# Rimosso soggetto: 32
# Percentuale attuale di missing values: 10.70%
# Numero di soggetti rimanenti: 747
# Rimosso soggetto: 33
# Percentuale attuale di missing values: 10.69%
# Numero di soggetti rimanenti: 746
# Rimosso soggetto: 34
# Percentuale attuale di missing values: 10.68%
# Numero di soggetti rimanenti: 745
# Rimosso soggetto: 35
# Percentuale attuale di missing values: 10.67%
# Numero di soggetti rimanenti: 744
# Rimosso soggetto: 36
# Percentuale attuale di missing values: 10.67%
# Numero di soggetti rimanenti: 743
# Rimosso soggetto: 37
# Percentuale attuale di missing values: 10.66%
# Numero di soggetti rimanenti: 742
# Rimosso soggetto: 52
# Percentuale attuale di missing values: 10.65%
# Numero di soggetti rimanenti: 741
# Rimosso soggetto: 53
# Percentuale attuale di missing values: 10.64%
# Numero di soggetti rimanenti: 740
# Rimosso soggetto: 54
# Percentuale attuale di missing values: 10.63%
# Numero di soggetti rimanenti: 739
# Rimosso soggetto: 55
# Percentuale attuale di missing values: 10.63%
# Numero di soggetti rimanenti: 738
# Rimosso soggetto: 56
# Percentuale attuale di missing values: 10.62%
# Numero di soggetti rimanenti: 737
# Rimosso soggetto: 57
# Percentuale attuale di missing values: 10.61%
# Numero di soggetti rimanenti: 736
# Rimosso soggetto: 58
# Percentuale attuale di missing values: 10.60%
# Numero di soggetti rimanenti: 735
# Rimosso soggetto: 59
# Percentuale attuale di missing values: 10.59%
# Numero di soggetti rimanenti: 734
# Rimosso soggetto: 60
# Percentuale attuale di missing values: 10.58%
# Numero di soggetti rimanenti: 733
# Rimosso soggetto: 61
# Percentuale attuale di missing values: 10.58%
# Numero di soggetti rimanenti: 732
# Rimosso soggetto: 62
# Percentuale attuale di missing values: 10.57%
# Numero di soggetti rimanenti: 731
# Rimosso soggetto: 63
# Percentuale attuale di missing values: 10.56%
# Numero di soggetti rimanenti: 730
# Rimosso soggetto: 64
# Percentuale attuale di missing values: 10.55%
# Numero di soggetti rimanenti: 729
# Rimosso soggetto: 120
# Percentuale attuale di missing values: 10.54%
# Numero di soggetti rimanenti: 728
# Rimosso soggetto: 121
# Percentuale attuale di missing values: 10.53%
# Numero di soggetti rimanenti: 727
# Rimosso soggetto: 122
# Percentuale attuale di missing values: 10.53%
# Numero di soggetti rimanenti: 726
# Rimosso soggetto: 123
# Percentuale attuale di missing values: 10.52%
# Numero di soggetti rimanenti: 725
# Rimosso soggetto: 124
# Percentuale attuale di missing values: 10.51%
# Numero di soggetti rimanenti: 724
# Rimosso soggetto: 125
# Percentuale attuale di missing values: 10.50%
# Numero di soggetti rimanenti: 723
# Rimosso soggetto: 126
# Percentuale attuale di missing values: 10.49%
# Numero di soggetti rimanenti: 722
# Rimosso soggetto: 127
# Percentuale attuale di missing values: 10.48%
# Numero di soggetti rimanenti: 721
# Rimosso soggetto: 128
# Percentuale attuale di missing values: 10.47%
# Numero di soggetti rimanenti: 720
# Rimosso soggetto: 129
# Percentuale attuale di missing values: 10.47%
# Percentuale attuale di missing values: 10.20%
# Numero di soggetti rimanenti: 689
# Rimosso soggetto: 331
# Percentuale attuale di missing values: 10.19%
# Numero di soggetti rimanenti: 688
# Rimosso soggetto: 332
# Percentuale attuale di missing values: 10.18%
# Numero di soggetti rimanenti: 687
# Rimosso soggetto: 333
# Percentuale attuale di missing values: 10.17%
# Numero di soggetti rimanenti: 686
# Rimosso soggetto: 334
# Percentuale attuale di missing values: 10.16%
# Numero di soggetti rimanenti: 685
# Rimosso soggetto: 335
# Percentuale attuale di missing values: 10.15%
# Numero di soggetti rimanenti: 684
# Rimosso soggetto: 336
# Percentuale attuale di missing values: 10.14%
# Numero di soggetti rimanenti: 683
# Rimosso soggetto: 337
# Percentuale attuale di missing values: 10.13%
# Numero di soggetti rimanenti: 682
# Rimosso soggetto: 338
# Percentuale attuale di missing values: 10.12%
# Numero di soggetti rimanenti: 681
# Rimosso soggetto: 339
# Percentuale attuale di missing values: 10.11%
# Numero di soggetti rimanenti: 680
# Rimosso soggetto: 340
# Percentuale attuale di missing values: 10.10%
# Numero di soggetti rimanenti: 679
# Rimosso soggetto: 341
# Percentuale attuale di missing values: 10.09%
# Numero di soggetti rimanenti: 678
# Rimosso soggetto: 342
# Percentuale attuale di missing values: 10.08%
# Numero di soggetti rimanenti: 677
# Rimosso soggetto: 343
# Percentuale attuale di missing values: 10.07%
# Numero di soggetti rimanenti: 676
# Rimosso soggetto: 344
# Percentuale attuale di missing values: 10.06%
# Numero di soggetti rimanenti: 675
# Rimosso soggetto: 345
# Percentuale attuale di missing values: 10.05%
# Numero di soggetti rimanenti: 674
# Rimosso soggetto: 346
# Percentuale attuale di missing values: 10.04%
# Numero di soggetti rimanenti: 673
# Rimosso soggetto: 347
# Percentuale attuale di missing values: 10.03%
# Numero di soggetti rimanenti: 672
# Rimosso soggetto: 348
# Percentuale attuale di missing values: 10.02%
# Numero di soggetti rimanenti: 671
# Rimosso soggetto: 349
# Percentuale attuale di missing values: 10.01%
# Numero di soggetti rimanenti: 670
# Rimosso soggetto: 350
# Percentuale attuale di missing values: 10.00%
# Numero di soggetti rimanenti: 669
# Rimosso soggetto: 351
# Percentuale attuale di missing values: 9.99%
# Numero di soggetti rimanenti: 668
#    SITE_ID  DX_GROUP  AGE_AT_SCAN  SEX    FIQ    VIQ    PIQ FIQ_TEST_TYPE  \
# 0  CALTECH         1         55.4    1  126.0  118.0  128.0          WASI
# 1  CALTECH         1         22.9    1  107.0  119.0   93.0          WASI
# 2  CALTECH         1         39.2    1   93.0   80.0  108.0          WASI
# 3  CALTECH         1         22.8    1  106.0   94.0  118.0          WASI
# 4  CALTECH         1         34.6    2  133.0  135.0  122.0          WASI
#
#   VIQ_TEST_TYPE PIQ_TEST_TYPE  ADI_R_VERBAL_TOTAL_BV  ADOS_TOTAL
# 0          WASI          WASI                    NaN         9.0
# 1          WASI          WASI                   17.0         8.0
# 2          WASI          WASI                   18.0        20.0
# 3          WASI          WASI                   12.0        12.0
# 4          WASI          WASI                   11.0        13.0
#       SITE_ID  DX_GROUP  AGE_AT_SCAN  SEX    FIQ    VIQ    PIQ FIQ_TEST_TYPE  \
# 0     CALTECH         1        55.40    1  126.0  118.0  128.0          WASI
# 1     CALTECH         1        22.90    1  107.0  119.0   93.0          WASI
# 2     CALTECH         1        39.20    1   93.0   80.0  108.0          WASI
# 3     CALTECH         1        22.80    1  106.0   94.0  118.0          WASI
# 4     CALTECH         1        34.60    2  133.0  135.0  122.0          WASI
# ...       ...       ...          ...  ...    ...    ...    ...           ...
# 1107     YALE         1        11.08    2   90.0   91.0   89.0     DAS_II_SA
# 1108     YALE         1         7.00    1   99.0   90.0   98.0     DAS_II_SA
# 1109     YALE         1        11.08    1   61.0   66.0   60.0     DAS_II_SA
# 1110     YALE         1         9.50    2   88.0  103.0   84.0     DAS_II_SA
# 1111     YALE         1        14.42    1   77.0   72.0   75.0     DAS_II_SA
#
#      VIQ_TEST_TYPE PIQ_TEST_TYPE  ADI_R_VERBAL_TOTAL_BV  ADOS_TOTAL
# 0             WASI          WASI                    NaN         9.0
# 1             WASI          WASI                   17.0         8.0
# 2             WASI          WASI                   18.0        20.0
# 3             WASI          WASI                   12.0        12.0
# 4             WASI          WASI                   11.0        13.0
# ...            ...           ...                    ...         ...
# 1107     DAS_II_SA     DAS_II_SA                   10.0         NaN
# 1108     DAS_II_SA     DAS_II_SA                   23.0         NaN
# 1109     DAS_II_SA     DAS_II_SA                   24.0         NaN
# 1110     DAS_II_SA     DAS_II_SA                   11.0         NaN
# 1111     DAS_II_SA     DAS_II_SA                   11.0         NaN
#
# [668 rows x 12 columns]

# %% [markdown]
# controlliamo che non abbia creato unbalancing

# %%
# Calcola il conteggio delle classi per DX_GROUP
class_counts_DX_GROUP = ASD_phenotypic_cleaned['DX_GROUP'].value_counts()


# Stampa il conteggio delle classi per DX_GROUP
print("Conteggio delle classi per DX_GROUP:")
print(class_counts_DX_GROUP)

# Visualizza la distribuzione delle classi per DX_GROUP
class_counts_DX_GROUP.plot(kind='bar', color='blue')
plt.title('Distribuzione delle classi per DX_GROUP')
plt.xlabel('Classe')
plt.ylabel('Numero di campioni')
plt.xticks(rotation=0)
plt.show()

# Calcola le proporzioni delle classi per DX_GROUP
class_proportions_DX_GROUP = ASD_phenotypic_cleaned['DX_GROUP'].value_counts(normalize=True)

# Stampa le proporzioni delle classi per DX_GROUP
print("\nProporzioni delle classi per DX_GROUP:")
print(class_proportions_DX_GROUP)
# Out:
# Conteggio delle classi per DX_GROUP:
# DX_GROUP
# 1    403
# 2    265
# Name: count, dtype: int64
# Proporzioni delle classi per DX_GROUP:
# DX_GROUP
# 1    0.603293
# 2    0.396707
# Name: proportion, dtype: float64

# %% [markdown]
# controlliamo meassing values per features e soggetti

# %%
ASD_phenotypic_cleaned.isna().sum()
# Out:
# SITE_ID                    0
# DX_GROUP                   0
# AGE_AT_SCAN                0
# SEX                        0
# FIQ                        1
# VIQ                        0
# PIQ                        0
# FIQ_TEST_TYPE             66
# VIQ_TEST_TYPE             23
# PIQ_TEST_TYPE             23
# ADI_R_VERBAL_TOTAL_BV    351
# ADOS_TOTAL               337
# dtype: int64

# %%
# Count of the missing values

nan_values = ASD_phenotypic_cleaned.isna().sum() 
nan_sorted = nan_values.sort_values(ascending=False)

total_rows = ASD_phenotypic_cleaned.shape[0]
percent_missing = (nan_sorted / total_rows) * 100

# We implemented a function "select_columns", that is able to define wich columns are numerical
# and which ones are categorical (also redefine the objects as categorical in the dataset)
numeric_columns, categorical_columns, ASD_phenotypic_cleaned = of.select_columns(ASD_phenotypic_cleaned)

# We plot the distribution of missing values, with the specification of numeric and categorical columns
of.plot_missing_values(percent_missing, numeric_columns, legend=True)

# %%
# Calcolo dei valori mancanti per soggetto anziché per feature
nan_values_per_subject = ASD_phenotypic_cleaned.T.isna().sum()

# Ordinamento dei valori mancanti
subjects_with_nan_sorted = nan_values_per_subject.sort_values(ascending=False)


of.plot_missing_values(subjects_with_nan_sorted, nan_values_per_subject, legend=False)
plt.ylabel('Subjects')
plt.yticks([])
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Va bene

# %%
# Store them in a new dataset called ASD_clinical
ASD_clinical = ASD_phenotypic_cleaned[['DX_GROUP']]
# Drop  columns DX_GROUP e fai storage a parte
ASD_phenotypic = ASD_phenotypic_cleaned.drop(columns=['DX_GROUP'])

# %%
ASD_clinical
# Out:
#       DX_GROUP
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 1107         1
# 1108         1
# 1109         1
# 1110         1
# 1111         1
#
# [668 rows x 1 columns]

# %%
ASD_phenotypic
# Out:
#       SITE_ID  AGE_AT_SCAN  SEX    FIQ    VIQ    PIQ FIQ_TEST_TYPE  \
# 0     CALTECH        55.40    1  126.0  118.0  128.0          WASI
# 1     CALTECH        22.90    1  107.0  119.0   93.0          WASI
# 2     CALTECH        39.20    1   93.0   80.0  108.0          WASI
# 3     CALTECH        22.80    1  106.0   94.0  118.0          WASI
# 4     CALTECH        34.60    2  133.0  135.0  122.0          WASI
# ...       ...          ...  ...    ...    ...    ...           ...
# 1107     YALE        11.08    2   90.0   91.0   89.0     DAS_II_SA
# 1108     YALE         7.00    1   99.0   90.0   98.0     DAS_II_SA
# 1109     YALE        11.08    1   61.0   66.0   60.0     DAS_II_SA
# 1110     YALE         9.50    2   88.0  103.0   84.0     DAS_II_SA
# 1111     YALE        14.42    1   77.0   72.0   75.0     DAS_II_SA
#
#      VIQ_TEST_TYPE PIQ_TEST_TYPE  ADI_R_VERBAL_TOTAL_BV  ADOS_TOTAL
# 0             WASI          WASI                    NaN         9.0
# 1             WASI          WASI                   17.0         8.0
# 2             WASI          WASI                   18.0        20.0
# 3             WASI          WASI                   12.0        12.0
# 4             WASI          WASI                   11.0        13.0
# ...            ...           ...                    ...         ...
# 1107     DAS_II_SA     DAS_II_SA                   10.0         NaN
# 1108     DAS_II_SA     DAS_II_SA                   23.0         NaN
# 1109     DAS_II_SA     DAS_II_SA                   24.0         NaN
# 1110     DAS_II_SA     DAS_II_SA                   11.0         NaN
# 1111     DAS_II_SA     DAS_II_SA                   11.0         NaN
#
# [668 rows x 11 columns]

# %%
ASD_phenotypic.head().T
# Out:
#                              0        1        2        3        4
# SITE_ID                CALTECH  CALTECH  CALTECH  CALTECH  CALTECH
# AGE_AT_SCAN               55.4     22.9     39.2     22.8     34.6
# SEX                          1        1        1        1        2
# FIQ                      126.0    107.0     93.0    106.0    133.0
# VIQ                      118.0    119.0     80.0     94.0    135.0
# PIQ                      128.0     93.0    108.0    118.0    122.0
# FIQ_TEST_TYPE             WASI     WASI     WASI     WASI     WASI
# VIQ_TEST_TYPE             WASI     WASI     WASI     WASI     WASI
# PIQ_TEST_TYPE             WASI     WASI     WASI     WASI     WASI
# ADI_R_VERBAL_TOTAL_BV      NaN     17.0     18.0     12.0     11.0
# ADOS_TOTAL                 9.0      8.0     20.0     12.0     13.0

# %% [markdown]
# ##  Preprocessing of Categorical Features

# %% [markdown]
# First of all, in order to avoid mismatch between attributes that are the same, but wrote with upper or lower characters, we decide to unify them.

# %%
#We make all the caracters upper for all the categorical features
category_columns_upper = ASD_phenotypic.select_dtypes(include='category').apply(lambda x: x.str.upper())

#We now modify them in the dataset
ASD_phenotypic[category_columns_upper.columns] = category_columns_upper

# %%
numeric_columns, categorical_columns, ASD_phenotypic = of.select_columns(ASD_phenotypic)

# %%
# We obtain the names of the features 
categorical_column_names = categorical_columns.tolist()
categorical_column_names
# Out:
# ['SITE_ID', 'FIQ_TEST_TYPE', 'VIQ_TEST_TYPE', 'PIQ_TEST_TYPE']

# %% [markdown]
# ### SITE_ID

# %% [markdown]
# SITE_ID refers to the place where the data from the subject was recluted.

# %%
# Accesso a una specifica colonna categorica utilizzando la lista di nomi
specific_category_column = ASD_phenotypic[categorical_column_names[0]].value_counts(dropna=False)
specific_category_column
# Out:
# SITE_ID
# NYU         152
# USM         101
# UCLA_1       82
# PITT         57
# YALE         56
# UM_1         53
# STANFORD     40
# UCLA_2       27
# SDSU         23
# TRINITY      23
# CALTECH      18
# UM_2         18
# CMU          14
# SBL           4
# Name: count, dtype: int64

# %% [markdown]
# There is data that has been collected from the same center that we decide to unify.

# %%
# We create a function to replace the categories for the indicated cases

def replace_categories(category):
    if "UCLA" in category:
        return "UCLA"
    if "LEUVEN" in category:
        return "LEUVEN"
    if "UM" in category:
        return "UM"
    else:
        return category

# Then we apply the replace function
ASD_phenotypic[categorical_column_names[0]] = ASD_phenotypic[categorical_column_names[0]].apply(replace_categories).astype('category')

# Now we check the new order
specific_category_column = ASD_phenotypic[categorical_column_names[0]].value_counts(dropna=False)
specific_category_column
# Out:
# SITE_ID
# NYU         152
# UCLA        109
# USM         101
# UM           71
# PITT         57
# YALE         56
# STANFORD     40
# SDSU         23
# TRINITY      23
# CALTECH      18
# CMU          14
# SBL           4
# Name: count, dtype: int64

# %% [markdown]
# ### FIQ_TEST_TYPE, VIQ_TEST_TYPE and PIQ_TEST_TYPE

# %% [markdown]
# FIQ_TEST_TYPE, VIQ_TEST_TYPE and PIQ_TEST_TYPE refers to the type of test that each center chose to get the information of FIQ_TEST, VIQ_TEST and PIQ_TEST respectively. As we want our clustering algorithm to be as most general as possible, we want to be able to categorize subjects in despise of the test used by the centers to get the data. So we decide to drop this feature as well.
#
# Note that if in a future we will be interested in to analyze if there are differences between the clustering score obtained using the result for each difference test we'll can retrieve the information opportunely.

# %%
for i in range (1,4):
    specific_category_column = ASD_phenotypic[categorical_column_names[i]].value_counts(dropna=False)
    print(specific_category_column)
    print('______________________________________\n')
# Out:
# FIQ_TEST_TYPE
# WASI                  460
# NaN                    66
# DAS_II_SA              56
# WISC_IV_FULL           48
# WISC                   15
# WAIS_III               14
# WISC_IV_4_SUBTESTS      5
# WAIS                    3
# WISC_III                1
# Name: count, dtype: int64
# ______________________________________
#
# VIQ_TEST_TYPE
# WASI            443
# DAS_II_SA        69
# WISC_IV_FULL     47
# PPVT             38
# NaN              23
# WISC             15
# WAIS_III         14
# PPVT              8
# WASI              5
# WAIS              3
# STANFORD          1
# WISC4             1
# WISC_III          1
# Name: count, dtype: int64
# ______________________________________
#
# PIQ_TEST_TYPE
# WASI            443
# DAS_II_SA        70
# WISC_IV_FULL     47
# RAVENS           38
# NaN              23
# WISC             15
# WAIS_III         14
# RAVENS            7
# WASI              5
# WAIS              3
# STANFORD          1
# WISC4             1
# WISC_III          1
# Name: count, dtype: int64
# ______________________________________

# %%
# We create a function to replace the categories for the indicated cases

def replace_categories(category):
    if pd.isna(category):  # Controlla se il valore è NaN
        return category  # Se è NaN, restituisci lo stesso valore
    if "WASI" in category:
        return "WASI"
    if "WISC" in category:
        return "WISC"
    if "WAIS" in category:
        return "WAIS"
    if "DAS" in category:
        return "DAS"
    if "HAWIK" in category:
        return "HAWIK"
    if "PPVT" in category:
        return "PPVT"
    if "RAVENS" in category:
        return "RAVENS"
   
    else:
        return category

for i in range (1,4):
    ASD_phenotypic[categorical_column_names[i]] = ASD_phenotypic[categorical_column_names[i]].apply(replace_categories).astype('category')
    specific_category_column = ASD_phenotypic[categorical_column_names[i]].value_counts(dropna=False)
    print(specific_category_column)
    print('______________________________________\n')
# Out:
# FIQ_TEST_TYPE
# WASI    460
# WISC     69
# NaN      66
# DAS      56
# WAIS     17
# Name: count, dtype: int64
# ______________________________________
#
# VIQ_TEST_TYPE
# WASI        448
# DAS          69
# WISC         64
# PPVT         46
# NaN          23
# WAIS         17
# STANFORD      1
# Name: count, dtype: int64
# ______________________________________
#
# PIQ_TEST_TYPE
# WASI        448
# DAS          70
# WISC         64
# RAVENS       45
# NaN          23
# WAIS         17
# STANFORD      1
# Name: count, dtype: int64
# ______________________________________

# %% [markdown]
# ## Managing Missing Values

# %% [markdown]
# We display the general information of the dataset once again in order to have a better view of the dataset, now that we have performed some changes.

# %%
ASD_phenotypic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 668 entries, 0 to 1111
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SITE_ID                668 non-null    category
#  1   AGE_AT_SCAN            668 non-null    float64
#  2   SEX                    668 non-null    int64
#  3   FIQ                    667 non-null    float64
#  4   VIQ                    668 non-null    float64
#  5   PIQ                    668 non-null    float64
#  6   FIQ_TEST_TYPE          602 non-null    category
#  7   VIQ_TEST_TYPE          645 non-null    category
#  8   PIQ_TEST_TYPE          645 non-null    category
#  9   ADI_R_VERBAL_TOTAL_BV  317 non-null    float64
#  10  ADOS_TOTAL             331 non-null    float64
# dtypes: category(4), float64(6), int64(1)
# memory usage: 61.5 KB

# %%
ASD_phenotypic.describe()
# Out:
#        AGE_AT_SCAN         SEX         FIQ         VIQ         PIQ  \
# count   668.000000  668.000000  667.000000  668.000000  668.000000
# mean     16.276463    1.118263  107.107946  106.362275  106.287425
# std       7.183633    0.323162   15.885109   16.595927   16.113020
# min       6.470000    1.000000   41.000000   42.000000   37.000000
# 25%      11.658575    1.000000   97.000000   96.000000   96.000000
# 50%      14.260000    1.000000  107.000000  107.000000  107.000000
# 75%      18.495100    1.000000  119.000000  118.000000  118.000000
# max      64.000000    2.000000  148.000000  180.000000  157.000000
#
#        ADI_R_VERBAL_TOTAL_BV  ADOS_TOTAL
# count             317.000000  331.000000
# mean               16.059937   10.888218
# std                 4.262681    4.760591
# min                 4.000000    0.000000
# 25%                13.000000    8.000000
# 50%                16.000000   11.000000
# 75%                19.000000   14.000000
# max                26.000000   22.000000

# %% [markdown]
# Now we are going to fullfill the missing values for all the features, based on an analysis of the information delivered by each one.

# %% [markdown]
# ### IQ Test Type

# %% [markdown]
# We use features FIQ, VIQ and PIQ in order to fill some values in FIQ-TEST-TYPE, VIQ-TEST-TYPE, PIQ-TEST-TYPE.
# Since the presence of more missing values in "Type" features, we make a comparison for each couple of features. For instance: if for FIQ there is a value and for FIQ-TEST-TYPE there is a missing one, we fill it with the MODE.

# %%
# Lista delle coppie di features da controllare
feature_pairs = [
    ('FIQ_TEST_TYPE', 'FIQ'),
    ('PIQ_TEST_TYPE', 'PIQ'),
    ('VIQ_TEST_TYPE', 'VIQ')]

# Iteriamo su ogni coppia di features
for test_type_col, score_col in feature_pairs:
    # Iteriamo su ogni riga del DataFrame
    for index, row in ASD_phenotypic.iterrows():
        # Controlliamo se il valore nella colonna 'test_type_col' è mancante
        if pd.isnull(row[test_type_col]):
            # Se il valore nella colonna 'score_col' è presente
            if not pd.isnull(row[score_col]):
                # Calcoliamo la moda di 'test_type_col'
                mode_test_type = ASD_phenotypic[test_type_col].mode()[0]
                # Sostituiamo il valore mancante nella colonna 'test_type_col' con la moda
                ASD_phenotypic.at[index, test_type_col] = mode_test_type
            # Se entrambi i valori in 'test_type_col' e 'score_col' sono mancanti
            elif pd.isnull(row[score_col]):
                # Verifichiamo se "NOT_AVAILABLE" è già presente tra le categorie della colonna
                if "NOT_AVAILABLE" not in ASD_phenotypic[test_type_col].cat.categories:
                    # Aggiungiamo "NOT_AVAILABLE" come nuova categoria
                    ASD_phenotypic[test_type_col] = ASD_phenotypic[test_type_col].cat.add_categories("NOT_AVAILABLE")
                # Assegniamo la categoria 'NOT_AVAILABLE' a 'test_type_col'
                ASD_phenotypic.at[index, test_type_col] = 'NOT_AVAILABLE'

# %% [markdown]
# ### Test Scores

# %% [markdown]
# ##### Data Standarization

# %% [markdown]
# Before starting to fill the missing values, we note that as the data for the variables FIQ, VIQ, PIQ was obtained with different tests, there are also different scales for the scores to take into account. In this way, we prefer to apply a standardization so we have all the score on the same scale.

# %%
#For FIQ, the score scale is between 30-170 if the test taken was "DAS", otherwise is 50-160.
#We will unify all the data to the larger scale, i.e. 50-160

# We start defining the condition
condition = (ASD_phenotypic['FIQ_TEST_TYPE'] == 'DAS') | (ASD_phenotypic['FIQ'] < 50) | (ASD_phenotypic['FIQ'] > 160)

# Then we standarize the values dictated by the condition, to the new scale
ASD_phenotypic['FIQ'] = np.where(condition, 
                        (ASD_phenotypic['FIQ'] - 30) / (170 - 30) * (160 - 50) + 50, 
                        ASD_phenotypic['FIQ'])

# %%
#For VIQ, the score scale is between 31-169 if the test taken was "DAS", 
#between 36-164 if the test taken was "STANFORD",
 #between 40-160 if the test taken was "PPVT",  otherwise is 50-160.
#We will unify all the data to the more common used scale, i.e. 50-160

for i in ASD_phenotypic.index:
    test_type = ASD_phenotypic['VIQ_TEST_TYPE'][i]
    current_value = ASD_phenotypic['VIQ'][i]
    if (test_type == 'DAS') or (current_value <36) or (current_value > 164):
        ASD_phenotypic.loc[i, 'VIQ'] = (current_value - 31) / (169 - 31) * (160 - 50) + 50
    elif (test_type == 'STANFORD') or (current_value <40) or (current_value > 160):
        ASD_phenotypic.loc[i, 'VIQ'] = (current_value - 36) / (164 - 36) * (160 - 50) + 50
    elif (test_type == 'PPVT') or (current_value <50) or (current_value > 160):
        ASD_phenotypic.loc[i, 'VIQ'] = (current_value - 40) / (160 - 40) * (160 - 50) + 50

# %%
#For PIQ, the score scale is between 31-166 if the test taken was "DAS", 
#between 36-164 if the test taken was "STANFORD",
 #between 50-160 if the test taken was "RAVENS",  otherwise is 53-160.
#We will unify all the data to the more common used scale,, i.e. 50-160

for i in ASD_phenotypic.index:
    test_type = ASD_phenotypic['PIQ_TEST_TYPE'][i]
    current_value = ASD_phenotypic['PIQ'][i]
    if (test_type == 'DAS') or (current_value <36) or (current_value > 164):
        ASD_phenotypic.loc[i, 'VIQ'] = (current_value - 31) / (166 - 31) * (160 - 50) + 50
    elif (test_type == 'STANFORD') or (current_value <50) or (current_value > 160):
        ASD_phenotypic.loc[i, 'VIQ'] = (current_value - 36) / (164 - 36) * (160 - 50) + 50

# %%
ASD_phenotypic.describe()
# Out:
#        AGE_AT_SCAN         SEX         FIQ         VIQ         PIQ  \
# count   668.000000  668.000000  667.000000  668.000000  668.000000
# mean     16.276463    1.118263  107.531913  106.976190  106.287425
# std       7.183633    0.323162   15.338886   15.782631   16.113020
# min       6.470000    1.000000   58.642857   54.888889   37.000000
# 25%      11.658575    1.000000   97.000000   97.000000   96.000000
# 50%      14.260000    1.000000  107.500000  108.000000  107.000000
# 75%      18.495100    1.000000  119.000000  118.000000  118.000000
# max      64.000000    2.000000  148.000000  168.768116  157.000000
#
#        ADI_R_VERBAL_TOTAL_BV  ADOS_TOTAL
# count             317.000000  331.000000
# mean               16.059937   10.888218
# std                 4.262681    4.760591
# min                 4.000000    0.000000
# 25%                13.000000    8.000000
# 50%                16.000000   11.000000
# 75%                19.000000   14.000000
# max                26.000000   22.000000

# %% [markdown]
# ### ADOS_TOTAL

# %% [markdown]
# The feature "ADOS_TOTAL" is simply the sum of the scores obtained by "ADOS_COMM" and "ADOS_SOCIAL", so we can reduce the amount of missing values using the values of those features.

# %%
for i in ASD_phenotypic["ADOS_TOTAL"].index:
    ados_comm = ASD_phenotypic_original["ADOS_COMM"][i]
    ados_social = ASD_phenotypic_original["ADOS_SOCIAL"][i]
    if not pd.isna(ados_comm) and not pd.isna(ados_social):
        ASD_phenotypic.loc[i, "ADOS_TOTAL"] = ados_comm + ados_social

# %% [markdown]
# #### Test scores filling

# %% [markdown]
# We decided that to fill the missing values of the test subministred
# it should be good to rely on the standard score achieved by the mean
# of the global population (if the statistics are available in the literature) or the cutoff for the diagnostic of ASD,
# otherwise we will use the mean extracted from our dataset.
#
# So for the features "FIQ", "VIQ", "PIQ", "ADOS_TOTAL", "ADI_R_VERBAL_TOTAL_BV", we will apply a custom function that checks if there is an available value in literature for the mundial mean, otherwise assign the mean of the feature.

# %%
#list of features that we want to fill
test_score_fatures = ["FIQ", "VIQ", "PIQ", "ADOS_TOTAL", "ADI_R_VERBAL_TOTAL_BV"]

#function to fill with the global mean or the data feature mean
def test_score_fill (feature_value, feature_name, feature_mean):
    # We create a dictionary to store the literature mean scores
    literature_scores = {
    "FIQ": 97.34, # EEUU mean score retrieved from https://worldpopulationreview.com/country-rankings/average-iq-by-country
    "VIQ": 97.34, # EEUU mean score retrieved from https://worldpopulationreview.com/country-rankings/average-iq-by-country
    "PIQ": 97.34, # EEUU mean score retrieved from https://worldpopulationreview.com/country-rankings/average-iq-by-country
    "ADOS_TOTAL": 9.0, # autism cutoff retrieved from https://www.researchgate.net/figure/ADOS-maximum-score-and-cut-off-points-for-ASD-15_tbl1_361212648
    "ADI_R_VERBAL_TOTAL_BV": 8.0, # autism cutoff retrieved from https://www.researchgate.net/figure/Summary-statistics-for-ADI-R-domain-scores_tbl4_6709395
    }

    # Then we check which feature we obtained to decide if replace
    # using the value in the dictionary ot directly the mean of the data
    if pd.isna(feature_value):

        if feature_name in literature_scores:
            return literature_scores[feature_name]
        else:
            return feature_mean
    else:

        return feature_value

#loop for filling the features   
for feature_name in test_score_fatures:
    feature_mean = ASD_phenotypic_original[feature_name].mean()
    ASD_phenotypic[feature_name] = ASD_phenotypic[feature_name].apply(test_score_fill, args=(feature_name, feature_mean))

# %%
ASD_phenotypic.describe()
# Out:
#        AGE_AT_SCAN         SEX         FIQ         VIQ         PIQ  \
# count   668.000000  668.000000  668.000000  668.000000  668.000000
# mean     16.276463    1.118263  107.516655  106.976190  106.287425
# std       7.183633    0.323162   15.332455   15.782631   16.113020
# min       6.470000    1.000000   58.642857   54.888889   37.000000
# 25%      11.658575    1.000000   97.000000   97.000000   96.000000
# 50%      14.260000    1.000000  107.428571  108.000000  107.000000
# 75%      18.495100    1.000000  119.000000  118.000000  118.000000
# max      64.000000    2.000000  148.000000  168.768116  157.000000
#
#        ADI_R_VERBAL_TOTAL_BV    ADOS_TOTAL
# count             668.000000    668.000000
# mean               11.824850   -634.001497
# std                 4.983106   3512.608360
# min                 4.000000 -19998.000000
# 25%                 8.000000      9.000000
# 50%                 8.000000      9.000000
# 75%                16.000000     11.000000
# max                26.000000     22.000000

# %% [markdown]
# We can see, that if we display the information of the dataset, we have no longer presence of missing values.

# %%
ASD_phenotypic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 668 entries, 0 to 1111
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SITE_ID                668 non-null    category
#  1   AGE_AT_SCAN            668 non-null    float64
#  2   SEX                    668 non-null    int64
#  3   FIQ                    668 non-null    float64
#  4   VIQ                    668 non-null    float64
#  5   PIQ                    668 non-null    float64
#  6   FIQ_TEST_TYPE          668 non-null    category
#  7   VIQ_TEST_TYPE          668 non-null    category
#  8   PIQ_TEST_TYPE          668 non-null    category
#  9   ADI_R_VERBAL_TOTAL_BV  668 non-null    float64
#  10  ADOS_TOTAL             668 non-null    float64
# dtypes: category(4), float64(6), int64(1)
# memory usage: 61.5 KB

# %% [markdown]
# # Normalization

# %% [markdown]
# Since there are different scales of numerical features, we need to normalize them

# %%
def normalization (dataset):
    numeric_columns = dataset.select_dtypes(include=['float64', 'int64']).columns
    numeric_columns_names = numeric_columns.tolist()

    for column in numeric_columns_names:
        min = dataset[column].min()
        max = dataset[column].max()

        for i in dataset.index:
            current_value = dataset[column][i]
            dataset.loc[i, column] = (current_value - min) / (max - min)

    return dataset

# %%
ASD_phenotypic_normalized = normalization(ASD_phenotypic)
ASD_phenotypic_normalized.describe()
# Out:
#        AGE_AT_SCAN         SEX         FIQ         VIQ         PIQ  \
# count   668.000000  668.000000  668.000000  668.000000  668.000000
# mean      0.170458    0.118263    0.546949    0.457391    0.577395
# std       0.124868    0.323162    0.171586    0.138591    0.134275
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# 25%       0.090189    0.000000    0.429257    0.369787    0.491667
# 50%       0.135408    0.000000    0.545963    0.466381    0.583333
# 75%       0.209023    0.000000    0.675460    0.554193    0.675000
# max       1.000000    1.000000    1.000000    1.000000    1.000000
#
#        ADI_R_VERBAL_TOTAL_BV  ADOS_TOTAL
# count             668.000000  668.000000
# mean                0.355675    0.967233
# std                 0.226505    0.175455
# min                 0.000000    0.000000
# 25%                 0.181818    0.999351
# 50%                 0.181818    0.999351
# 75%                 0.545455    0.999451
# max                 1.000000    1.000000

# %% [markdown]
# # CORRELATION ANALYSIS

# %% [markdown]
# We perform correlation analysis separatamente, per numeriche e categoriche così da eliminarne alcune. Poi o ANOVA TEST O BOX PLOT O CAPIAMO PER TROVARE EVENTUALE CORRELAZIONE TRA NUMERICHE E CATEGORICHE.

# %% [markdown]
# ## Numerical Features

# %%
numeric_normalized = ASD_phenotypic_normalized.select_dtypes(include=['float64', 'int64'])

# Calcola la correlation matrix
correlation_matrix = numeric_normalized.corr()

# Visualizza la correlation matrix
print(correlation_matrix)
# Out:
#                        AGE_AT_SCAN       SEX       FIQ       VIQ       PIQ  \
# AGE_AT_SCAN               1.000000 -0.084471  0.069292  0.038103  0.075395
# SEX                      -0.084471  1.000000 -0.006536  0.010242 -0.033315
# FIQ                       0.069292 -0.006536  1.000000  0.850070  0.854322
# VIQ                       0.038103  0.010242  0.850070  1.000000  0.522485
# PIQ                       0.075395 -0.033315  0.854322  0.522485  1.000000
# ADI_R_VERBAL_TOTAL_BV    -0.161154  0.041743 -0.078508 -0.019186 -0.089709
# ADOS_TOTAL               -0.241459  0.040761 -0.048626 -0.027428 -0.059334
#
#                        ADI_R_VERBAL_TOTAL_BV  ADOS_TOTAL
# AGE_AT_SCAN                        -0.161154   -0.241459
# SEX                                 0.041743    0.040761
# FIQ                                -0.078508   -0.048626
# VIQ                                -0.019186   -0.027428
# PIQ                                -0.089709   -0.059334
# ADI_R_VERBAL_TOTAL_BV               1.000000    0.088039
# ADOS_TOTAL                          0.088039    1.000000

# %%
#CORRELATION MATRIX
# Calcola la correlazione tra le features normalizzate
correlation_matrix = numeric_normalized.corr()
numeric_normalized.T
f,ax = plt.subplots(figsize=(10, 8))
sns.heatmap(numeric_normalized.corr(), 
            annot=True, 
            linewidths=.5, 
            fmt= '.2f',
            ax=ax,
            vmin=-1, 
            vmax=1,
            cmap = "coolwarm")
plt.show()

# %% [markdown]
# ## Categorical features

# %%
numeric_columns, categorical_columns, ASD_phenotypic_normalized = of.select_columns(ASD_phenotypic_normalized)
# Compute Cramer's V for every pair of features
cramer_v_scores = pd.DataFrame(index=categorical_columns, columns=categorical_columns)
for feature1 in categorical_columns:
    for feature2 in categorical_columns:
        cramer_v = of.cramers_v(ASD_phenotypic_normalized[feature1], ASD_phenotypic_normalized[feature2])
        cramer_v_scores.loc[feature1, feature2] = cramer_v

# Plot heatmap of Cramer's V scores
plt.figure(figsize=(10, 8))
sns.heatmap(cramer_v_scores.astype(float), 
            annot=True, 
            linewidths=.5, 
            fmt='.2f',
            cmap="coolwarm")
plt.title("Cramer's V scores")
plt.show()

# %% [markdown]
# It seems that the information contained in VIQ_TEST_TYPE and PIQ_TEST_TYPE is almost the same, so it's reasonable to delete one of them. We decide to drop VIQ_TEST_TYPE and minimize the correlation between test types.

# %% [markdown]
# ### Visual overview of Categorical and Numerical

# %% [markdown]
# in order to evaluate eventual correlation

# %%
numeric_columns, categorical_columns, ASD_phenotypic_normalized = of.select_columns(ASD_phenotypic_normalized)

# Number of plots per row
plots_per_row = 4
num_plots = len(numeric_columns) * len(categorical_columns)
num_rows = (num_plots + plots_per_row - 1) // plots_per_row  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, plots_per_row, figsize=(20, num_rows * 5))

# Flatten axes for easy iteration
axes = axes.flatten()

plot_idx = 0
for numeric_col in numeric_columns:
    for cat_col in categorical_columns:
        ax = axes[plot_idx]
        
        sns.boxplot(x=cat_col, y=numeric_col, data=ASD_phenotypic_normalized,
                    order=ASD_phenotypic_normalized.groupby(cat_col, observed=False)[numeric_col].median().sort_values().index, ax=ax)
        
        # Highlight the median in red
        median = ASD_phenotypic_normalized.groupby(cat_col, observed=False)[numeric_col].median().sort_values()
        for i in range(len(median)):
            ax.plot(i, median.iloc[i], 'ro')
        
        ax.set_title(f'Boxplot of {numeric_col} by {cat_col}')
        ax.set_xlabel(cat_col)
        ax.set_ylabel(numeric_col)
        
        plot_idx += 1

# Remove any empty subplots
for i in range(plot_idx, len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# # PRE PROCESSED DATA STORAGE

# %%
# We decide to store in a file .csv the pre-processed dataset
ASD_phenotypic.to_csv('DataSets/Phenotypic Datasets/ASD_phenotypic_preprocessed.csv', index=False)
# And also the diagnostic groups
ASD_clinical.to_csv('DataSets/Phenotypic Datasets/ASD_clinical.csv', index=False)
